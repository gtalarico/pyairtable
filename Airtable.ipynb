# %% [markdown]
# ## Airtable Python Wrapper
#
# This Notebook shows typical usage for the airtable client.
# It requires `jupyter`, `pandas`, and and env var `AIRTABLE_KEY`
#
# The `base_key` included is a reference to [this base](https://airtable.com/shrREAyVIxHiBEZOF)

# %%
# %load_ext autoreload
# %autoreload


import os
from pprint import pprint
from airtable import Airtable
import pandas as pd

base_key = 'appNPoAJOyctb4MId'
table_name = 'Artists'
airtable = Airtable(base_key, table_name, api_key=os.environ['AIRTABLE_KEY'])
print(airtable)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <Airtable table:Artists>

# %%
# Get Iter with Max Records
pages = airtable.get_iter(maxRecords=2)

for page in pages:
    for record in page:
        pprint(record)
# Out:
# {'createdTime': '2015-02-09T23:41:00.000Z',
#  'fields': {'Attachments': [{'filename': 'flower_myth_1918.jpg',
#                              'id': 'attcYYG6sWWrgMFbw',
#                              'size': 99343,
#                              'thumbnails': {'full': {'height': 960,
#                                                      'url': 'https://dl.airtable.com/FsMUqTpoQkGePvM4jFtQ_full_flower_myth_1918.jpg',
#                                                      'width': 537},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/JK1oCURQrybztuRvEFcE_large_flower_myth_1918.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/fSnqEsyBSLCNTjgTU3aT_small_flower_myth_1918.jpg',
#                                                       'width': 20}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/gd7pFfNQQUSksZRDENBL_flower_myth_1918.jpg'},
#                             {'filename': 'insula-dulcamara-1938.jpg',
#                              'id': 'attwaeVMv3ccdV7r4',
#                              'size': 254393,
#                              'thumbnails': {'full': {'height': 575,
#                                                      'url': 'https://dl.airtable.com/2PHDPBTS4asVJTimMhwh_full_insula-dulcamara-1938.jpg',
#                                                      'width': 1200},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/zwN10PceSUSS0sHOG4DZ_large_insula-dulcamara-1938.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/sAWUOCFSFajKUcVewlvX_small_insula-dulcamara-1938.jpg',
#                                                       'width': 75}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/YB6WUlIRvm7UTlsFE4LL_insula-dulcamara-1938.jpg'},
#                             {'filename': 'Castle-and-Sun-by-Paul-Klee.jpg',
#                              'id': 'attPegJF1yGoR0Ctv',
#                              'size': 226289,
#                              'thumbnails': {'full': {'height': 821,
#                                                      'url': 'https://dl.airtable.com/cFBk0sn0TqaxCqlVr9xe_full_Castle-and-Sun-by-Paul-Klee.jpg',
#                                                      'width': 1000},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/36HAvrdrR4ejmzGPGp0h_large_Castle-and-Sun-by-Paul-Klee.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/0TB5iJL3QqGO2tE3CexU_small_Castle-and-Sun-by-Paul-Klee.jpg',
#                                                       'width': 44}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/wFCn3gvXR2OjIEtHTphC_Castle-and-Sun-by-Paul-Klee.jpg'}],
#             'Bio': 'Paul Klee\xa0was a\xa0painter\xa0born in\xa0'
#                    'Münchenbuchsee,\xa0Switzerland.\xa0His highly individual '
#                    'style was influenced by movements in art that included '
#                    'expressionism,\xa0cubism, and\xa0surrealism. He was also a '
#                    'student of\xa0orientalism. Klee was a natural draftsman '
#                    'who experimented with and eventually deeply explored\xa0'
#                    'color theory, writing about it extensively. His works '
#                    'reflect his dry humor and his sometimes childlike '
#                    'perspective, his personal moods and beliefs, and also his '
#                    'musicality.\n'
#                    'b. 18 December 1879 d. 29 June 1940 \n'
#                    '\n',
#             'Collection': ['recO1TajNOl2Nw50y'],
#             'Genre': ['Symbolism',
#                       'Surrealism',
#                       'Bauhaus',
#                       'Der Blaue Reiter',
#                       'Modern art'],
#             'Name': 'Paul Klee',
#             'On Display?': True},
#  'id': 'rec1M1K5xOETZ9dHy'}
# {'createdTime': '2015-02-09T23:40:46.000Z',
#  'fields': {'Attachments': [{'filename': 'clamdigger.jpg',
#                              'id': 'attCi0RHkx5DNhYBI',
#                              'size': 691995,
#                              'thumbnails': {'full': {'height': 1280,
#                                                      'url': 'https://dl.airtable.com/MYidE4A0RgGcUcrb9ayG_full_clamdigger.jpg',
#                                                      'width': 960},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/7xp2q0TJ6hV9FqNxSHwj_large_clamdigger.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/SvcuhJTtT8SIYWmR1Ijg_small_clamdigger.jpg',
#                                                       'width': 27}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/af1SXRnGwMaKYIntYegB_clamdigger.jpg'},
#                             {'filename': 'jack_and_bill_large.jpg',
#                              'id': 'att2F9zQ0iUqoUzuZ',
#                              'size': 3315526,
#                              'thumbnails': {'full': {'height': 2257,
#                                                      'url': 'https://dl.airtable.com/IfRMUgU3QWqzKuX47fir_full_jack_and_bill_large.jpg',
#                                                      'width': 2245},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/6rIgwI1S9C1zuL6Kkmqg_large_jack_and_bill_large.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/cqWmmEZERNApjilQI7Kl_small_jack_and_bill_large.jpg',
#                                                       'width': 36}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/bI8XHQz65cBlPsWBOPQk_jack_and_bill_large.jpg'},
#                             {'filename': 'abstraction-1950.jpg',
#                              'id': 'attPF1WOvQcDmLGiC',
#                              'size': 1039218,
#                              'thumbnails': {'full': {'height': 1293,
#                                                      'url': 'https://dl.airtable.com/bxDy6CaRZSGEaSyNqLZx_full_abstraction-1950.jpg',
#                                                      'width': 1600},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/QuzdlBtzRtenrU4DFNWb_large_abstraction-1950.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/vs9ojUenQuGTmDiHpNuQ_small_abstraction-1950.jpg',
#                                                       'width': 45}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/XIAiT3YDT5e1GePMVlLw_abstraction-1950.jpg'},
#                             {'filename': 'gotham-news.jpg',
#                              'id': 'att1GprK7x6odMvVe',
#                              'size': 658408,
#                              'thumbnails': {'full': {'height': 1052,
#                                                      'url': 'https://dl.airtable.com/zmF73R82Q96wZAUxqm3g_full_gotham-news.jpg',
#                                                      'width': 1200},
#                                             'large': {'height': 512,
#                                                       'url': 'https://dl.airtable.com/PY4hgrDRXWGP4IjSVMiQ_large_gotham-news.jpg',
#                                                       'width': 512},
#                                             'small': {'height': 36,
#                                                       'url': 'https://dl.airtable.com/Ur1b4gmsQVmsCXG9CSCv_small_gotham-news.jpg',
#                                                       'width': 41}},
#                              'type': 'image/jpeg',
#                              'url': 'https://dl.airtable.com/tqCmtNbbRYazTFyR24IA_gotham-news.jpg'}],
#             'Bio': 'Willem de Kooning was a\xa0Dutch American\xa0abstract '
#                    'expressionist\xa0artist who was born in\xa0Rotterdam, the '
#                    'Netherlands. In the post-World War II\xa0era, de Kooning '
#                    'painted in a style that came to be referred to as\xa0'
#                    'Abstract expressionism\xa0or Action painting, and was part '
#                    'of a group of artists that came to be known as the\xa0New '
#                    'York School.\xa0',
#             'Collection': ['recuxHgKyHX10T4S3'],
#             'Genre': ['Abstract Expressionism'],
#             'Name': 'Willem de Kooning'},
#  'id': 'rec3osnAbyGTxswiY'}

# %%
# Get All with Max Records
records = airtable.get_all(maxRecords=2)
    
df = pd.DataFrame.from_records((r['fields'] for r in records))
df.head()
# Out:
#                                          Attachments  \
# 0  [{'id': 'attcYYG6sWWrgMFbw', 'url': 'https://d...
# 1  [{'id': 'attCi0RHkx5DNhYBI', 'url': 'https://d...
#
#                                                  Bio           Collection  \
# 0  Paul Klee was a painter born in Münchenbuchsee...  [recO1TajNOl2Nw50y]
# 1  Willem de Kooning was a Dutch American abstrac...  [recuxHgKyHX10T4S3]
#
#                                                Genre               Name  \
# 0  [Symbolism, Surrealism, Bauhaus, Der Blaue Rei...          Paul Klee
# 1                           [Abstract Expressionism]  Willem de Kooning
#
#   On Display?
# 0        True
# 1         NaN

# %%
# Get All on a View - View has only One Record
records = airtable.get_all(view='Artists on display')
# pprint(records)
df = pd.DataFrame.from_records((r['fields'] for r in records))
df.head(3)
# Out:
#                                          Attachments  \
# 0  [{'id': 'attCE1L8ubR6Ciq80', 'url': 'https://d...
# 1  [{'id': 'attONu0jXlWNlHOxh', 'url': 'https://d...
# 2  [{'id': 'attwiwoecIfWHYlWm', 'url': 'https://d...
#
#                                                  Bio           Collection  \
# 0  Al Held began his painting career by exhibitin...  [recMxKoXA1F8L3uJF]
# 1  Mark Rothko is generally identified as an Abst...  [recMxKoXA1F8L3uJF]
# 2  Arshile Gorky had a seminal influence on Abstr...  [recMxKoXA1F8L3uJF]
#
#                                             Genre           Name  On Display?
# 0  [American Abstract Expressionism, Color Field]        Al Held         True
# 1  [American Abstract Expressionism, Color Field]    Mark Rothko         True
# 2            [Abstract Expressionism, Modern art]  Arshile Gorky         True

# %%
# Get All with Max Records, Fields
records = airtable.get_all(fields='Name', max_records=1)

for record in records[0:2]:
    pprint(record)
# Out:
# {'createdTime': '2015-02-09T23:41:00.000Z',
#  'fields': {'Name': 'Paul Klee'},
#  'id': 'rec1M1K5xOETZ9dHy'}

# %%
records = airtable.search('Name', "Paul Klee")
pprint([r['fields'] for r in records])
# Out:
# [{'Attachments': [{'filename': 'flower_myth_1918.jpg',
#                    'id': 'attcYYG6sWWrgMFbw',
#                    'size': 99343,
#                    'thumbnails': {'full': {'height': 960,
#                                            'url': 'https://dl.airtable.com/FsMUqTpoQkGePvM4jFtQ_full_flower_myth_1918.jpg',
#                                            'width': 537},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/JK1oCURQrybztuRvEFcE_large_flower_myth_1918.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/fSnqEsyBSLCNTjgTU3aT_small_flower_myth_1918.jpg',
#                                             'width': 20}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/gd7pFfNQQUSksZRDENBL_flower_myth_1918.jpg'},
#                   {'filename': 'insula-dulcamara-1938.jpg',
#                    'id': 'attwaeVMv3ccdV7r4',
#                    'size': 254393,
#                    'thumbnails': {'full': {'height': 575,
#                                            'url': 'https://dl.airtable.com/2PHDPBTS4asVJTimMhwh_full_insula-dulcamara-1938.jpg',
#                                            'width': 1200},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/zwN10PceSUSS0sHOG4DZ_large_insula-dulcamara-1938.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/sAWUOCFSFajKUcVewlvX_small_insula-dulcamara-1938.jpg',
#                                             'width': 75}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/YB6WUlIRvm7UTlsFE4LL_insula-dulcamara-1938.jpg'},
#                   {'filename': 'Castle-and-Sun-by-Paul-Klee.jpg',
#                    'id': 'attPegJF1yGoR0Ctv',
#                    'size': 226289,
#                    'thumbnails': {'full': {'height': 821,
#                                            'url': 'https://dl.airtable.com/cFBk0sn0TqaxCqlVr9xe_full_Castle-and-Sun-by-Paul-Klee.jpg',
#                                            'width': 1000},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/36HAvrdrR4ejmzGPGp0h_large_Castle-and-Sun-by-Paul-Klee.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/0TB5iJL3QqGO2tE3CexU_small_Castle-and-Sun-by-Paul-Klee.jpg',
#                                             'width': 44}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/wFCn3gvXR2OjIEtHTphC_Castle-and-Sun-by-Paul-Klee.jpg'}],
#   'Bio': 'Paul Klee\xa0was a\xa0painter\xa0born in\xa0Münchenbuchsee,\xa0'
#          'Switzerland.\xa0His highly individual style was influenced by '
#          'movements in art that included expressionism,\xa0cubism, and\xa0'
#          'surrealism. He was also a student of\xa0orientalism. Klee was a '
#          'natural draftsman who experimented with and eventually deeply '
#          'explored\xa0color theory, writing about it extensively. His works '
#          'reflect his dry humor and his sometimes childlike perspective, his '
#          'personal moods and beliefs, and also his musicality.\n'
#          'b. 18 December 1879 d. 29 June 1940 \n'
#          '\n',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Symbolism',
#             'Surrealism',
#             'Bauhaus',
#             'Der Blaue Reiter',
#             'Modern art'],
#   'Name': 'Paul Klee',
#   'On Display?': True}]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in _process_response(self, response)
#     141         try:
# --> 142             response.raise_for_status()
#     143         except requests.exceptions.HTTPError as exc:
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/.venv/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api.airtable.com/v0/appNPoAJOyctb4MId/Artists?filterByFormula=%7BOn+Display%7D%3D%27True%27
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-47-9e87c6193f55> in <module>
#       2 pprint([r['fields'] for r in records])
#       3
# ----> 4 records = airtable.search('On Display', "True")
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in search(self, field_name, field_value, record, **options)
#     336         formula = from_name_and_value(field_name, field_value)
#     337         options["formula"] = formula
# --> 338         records = self.get_all(**options)
#     339         return records
#     340
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in get_all(self, **options)
#     271         """
#     272         all_records = []
# --> 273         for records in self.get_iter(**options):
#     274             all_records.extend(records)
#     275         return all_records
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in get_iter(self, **options)
#     235         offset = None
#     236         while True:
# --> 237             data = self._get(self.url_table, offset=offset, **options)
#     238             records = data.get("records", [])
#     239             time.sleep(self.API_LIMIT)
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in _get(self, url, **params)
#     173     def _get(self, url, **params):
#     174         processed_params = self._process_params(params)
# --> 175         return self._request("get", url, params=processed_params)
#     176
#     177     def _post(self, url, json_data):
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in _request(self, method, url, params, json_data)
#     169     def _request(self, method, url, params=None, json_data=None):
#     170         response = self.session.request(method, url, params=params, json=json_data)
# --> 171         return self._process_response(response)
#     172
#     173     def _get(self, url, **params):
#
# ~/dev/repos/gtalarico/airtable-python-wrapper/airtable/airtable.py in _process_response(self, response)
#     159                 if "error" in error_dict:
#     160                     err_msg += " [Error: {}]".format(error_dict["error"])
# --> 161             raise requests.exceptions.HTTPError(err_msg)
#     162         else:
#     163             return response.json()
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api.airtable.com/v0/appNPoAJOyctb4MId/Artists?filterByFormula={On+Display}='True' (Decoded URL) [Error: {'type': 'INVALID_FILTER_BY_FORMULA', 'message': 'The formula for filtering records is invalid: Unknown field names: on display'}]

# %%
records = airtable.search('On Display?', "1")
pprint([r['fields'] for r in records])
# Out:
# [{'Attachments': [{'filename': 'flower_myth_1918.jpg',
#                    'id': 'attcYYG6sWWrgMFbw',
#                    'size': 99343,
#                    'thumbnails': {'full': {'height': 960,
#                                            'url': 'https://dl.airtable.com/FsMUqTpoQkGePvM4jFtQ_full_flower_myth_1918.jpg',
#                                            'width': 537},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/JK1oCURQrybztuRvEFcE_large_flower_myth_1918.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/fSnqEsyBSLCNTjgTU3aT_small_flower_myth_1918.jpg',
#                                             'width': 20}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/gd7pFfNQQUSksZRDENBL_flower_myth_1918.jpg'},
#                   {'filename': 'insula-dulcamara-1938.jpg',
#                    'id': 'attwaeVMv3ccdV7r4',
#                    'size': 254393,
#                    'thumbnails': {'full': {'height': 575,
#                                            'url': 'https://dl.airtable.com/2PHDPBTS4asVJTimMhwh_full_insula-dulcamara-1938.jpg',
#                                            'width': 1200},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/zwN10PceSUSS0sHOG4DZ_large_insula-dulcamara-1938.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/sAWUOCFSFajKUcVewlvX_small_insula-dulcamara-1938.jpg',
#                                             'width': 75}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/YB6WUlIRvm7UTlsFE4LL_insula-dulcamara-1938.jpg'},
#                   {'filename': 'Castle-and-Sun-by-Paul-Klee.jpg',
#                    'id': 'attPegJF1yGoR0Ctv',
#                    'size': 226289,
#                    'thumbnails': {'full': {'height': 821,
#                                            'url': 'https://dl.airtable.com/cFBk0sn0TqaxCqlVr9xe_full_Castle-and-Sun-by-Paul-Klee.jpg',
#                                            'width': 1000},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/36HAvrdrR4ejmzGPGp0h_large_Castle-and-Sun-by-Paul-Klee.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/0TB5iJL3QqGO2tE3CexU_small_Castle-and-Sun-by-Paul-Klee.jpg',
#                                             'width': 44}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/wFCn3gvXR2OjIEtHTphC_Castle-and-Sun-by-Paul-Klee.jpg'}],
#   'Bio': 'Paul Klee\xa0was a\xa0painter\xa0born in\xa0Münchenbuchsee,\xa0'
#          'Switzerland.\xa0His highly individual style was influenced by '
#          'movements in art that included expressionism,\xa0cubism, and\xa0'
#          'surrealism. He was also a student of\xa0orientalism. Klee was a '
#          'natural draftsman who experimented with and eventually deeply '
#          'explored\xa0color theory, writing about it extensively. His works '
#          'reflect his dry humor and his sometimes childlike perspective, his '
#          'personal moods and beliefs, and also his musicality.\n'
#          'b. 18 December 1879 d. 29 June 1940 \n'
#          '\n',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Symbolism',
#             'Surrealism',
#             'Bauhaus',
#             'Der Blaue Reiter',
#             'Modern art'],
#   'Name': 'Paul Klee',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'clamdigger.jpg',
#                    'id': 'attCi0RHkx5DNhYBI',
#                    'size': 691995,
#                    'thumbnails': {'full': {'height': 1280,
#                                            'url': 'https://dl.airtable.com/MYidE4A0RgGcUcrb9ayG_full_clamdigger.jpg',
#                                            'width': 960},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/7xp2q0TJ6hV9FqNxSHwj_large_clamdigger.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/SvcuhJTtT8SIYWmR1Ijg_small_clamdigger.jpg',
#                                             'width': 27}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/af1SXRnGwMaKYIntYegB_clamdigger.jpg'},
#                   {'filename': 'jack_and_bill_large.jpg',
#                    'id': 'att2F9zQ0iUqoUzuZ',
#                    'size': 3315526,
#                    'thumbnails': {'full': {'height': 2257,
#                                            'url': 'https://dl.airtable.com/IfRMUgU3QWqzKuX47fir_full_jack_and_bill_large.jpg',
#                                            'width': 2245},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/6rIgwI1S9C1zuL6Kkmqg_large_jack_and_bill_large.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/cqWmmEZERNApjilQI7Kl_small_jack_and_bill_large.jpg',
#                                             'width': 36}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/bI8XHQz65cBlPsWBOPQk_jack_and_bill_large.jpg'},
#                   {'filename': 'abstraction-1950.jpg',
#                    'id': 'attPF1WOvQcDmLGiC',
#                    'size': 1039218,
#                    'thumbnails': {'full': {'height': 1293,
#                                            'url': 'https://dl.airtable.com/bxDy6CaRZSGEaSyNqLZx_full_abstraction-1950.jpg',
#                                            'width': 1600},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/QuzdlBtzRtenrU4DFNWb_large_abstraction-1950.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/vs9ojUenQuGTmDiHpNuQ_small_abstraction-1950.jpg',
#                                             'width': 45}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/XIAiT3YDT5e1GePMVlLw_abstraction-1950.jpg'},
#                   {'filename': 'gotham-news.jpg',
#                    'id': 'att1GprK7x6odMvVe',
#                    'size': 658408,
#                    'thumbnails': {'full': {'height': 1052,
#                                            'url': 'https://dl.airtable.com/zmF73R82Q96wZAUxqm3g_full_gotham-news.jpg',
#                                            'width': 1200},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/PY4hgrDRXWGP4IjSVMiQ_large_gotham-news.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/Ur1b4gmsQVmsCXG9CSCv_small_gotham-news.jpg',
#                                             'width': 41}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/tqCmtNbbRYazTFyR24IA_gotham-news.jpg'}],
#   'Bio': 'Willem de Kooning was a\xa0Dutch American\xa0abstract '
#          'expressionist\xa0artist who was born in\xa0Rotterdam, the '
#          'Netherlands. In the post-World War II\xa0era, de Kooning painted in '
#          'a style that came to be referred to as\xa0Abstract expressionism\xa0'
#          'or Action painting, and was part of a group of artists that came to '
#          'be known as the\xa0New York School.\xa0',
#   'Collection': ['recuxHgKyHX10T4S3'],
#   'Genre': ['Abstract Expressionism'],
#   'Name': 'Willem de Kooning',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Vassily_Kandinsky,_1908_-_Houses_in_Munich-2.jpg',
#                    'id': 'attDOek21uHGARxIT',
#                    'size': 42446,
#                    'thumbnails': {'full': {'height': 473,
#                                            'url': 'https://dl.airtable.com/66M685YbQIy5sFx9VWG4_full_Vassily_Kandinsky%2C_1908_-_Houses_in_Munich-2.jpg',
#                                            'width': 586},
#                                   'large': {'height': 473,
#                                             'url': 'https://dl.airtable.com/xRGg8S5cQcuDUtz0To9f_large_Vassily_Kandinsky%2C_1908_-_Houses_in_Munich-2.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/21BPr0gAQC6OfrgygmOw_small_Vassily_Kandinsky%2C_1908_-_Houses_in_Munich-2.jpg',
#                                             'width': 45}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/4EVHAaNmSQKOB1fx1ocJ_Vassily_Kandinsky%2C_1908_-_Houses_in_Munich-2.jpg'},
#                   {'filename': 'Vassily_Kandinsky,_1908_-_Munich-Schwabing_with_the_Church_of_St-Ursula '
#                                '(1).jpg',
#                    'id': 'att7454vRQkzw5Q0r',
#                    'size': 73322,
#                    'thumbnails': {'full': {'height': 599,
#                                            'url': 'https://dl.airtable.com/4FUo6WsERIm2d7YagoP5_full_Vassily_Kandinsky%2C_1908_-_Munich-Schwabing_with_the_Church_of_St-Ursula%20(1).jpg',
#                                            'width': 416},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/0EI1ZwYkSlqgoi1oAlKU_large_Vassily_Kandinsky%2C_1908_-_Munich-Schwabing_with_the_Church_of_St-Ursula%20(1).jpg',
#                                             'width': 416},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/RX50sw6FQbe4U50wTvFA_small_Vassily_Kandinsky%2C_1908_-_Munich-Schwabing_with_the_Church_of_St-Ursula%20(1).jpg',
#                                             'width': 25}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/OOtFdbecQkmPsbvxY5sc_Vassily_Kandinsky%2C_1908_-_Munich-Schwabing_with_the_Church_of_St-Ursula%20(1).jpg'},
#                   {'filename': 'Vassily_Kandinsky,_1909_-_Murnau_train_et_château.jpg',
#                    'id': 'att4ae0DX9AmvC37u',
#                    'size': 107456,
#                    'thumbnails': {'full': {'height': 639,
#                                            'url': 'https://dl.airtable.com/aEYubaC2Q4uhHv7fakJH_full_Vassily_Kandinsky%2C_1909_-_Murnau_train_et_cha%CC%82teau.jpg',
#                                            'width': 883},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/xs9DQ33rQx6ymTbBC4fF_large_Vassily_Kandinsky%2C_1909_-_Murnau_train_et_cha%CC%82teau.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/0LvwMdngQiiB4TBmzAwy_small_Vassily_Kandinsky%2C_1909_-_Murnau_train_et_cha%CC%82teau.jpg',
#                                             'width': 50}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/WdPrzoF2SPejHrjCHADe_Vassily_Kandinsky%2C_1909_-_Murnau_train_et_cha%CC%82teau.jpg'},
#                   {'filename': 'Vassily_Kandinsky,_1927_-_Molle_rudesse.jpg',
#                    'id': 'attosA1td47YhpfJq',
#                    'size': 42833,
#                    'thumbnails': {'full': {'height': 365,
#                                            'url': 'https://dl.airtable.com/1cEAe9tDThyuF31H0xJX_full_Vassily_Kandinsky%2C_1927_-_Molle_rudesse.jpg',
#                                            'width': 520},
#                                   'large': {'height': 365,
#                                             'url': 'https://dl.airtable.com/H4iVpQStSuJqECVGGxWd_large_Vassily_Kandinsky%2C_1927_-_Molle_rudesse.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/Axesl1Rk6Cw5fks00QMw_small_Vassily_Kandinsky%2C_1927_-_Molle_rudesse.jpg',
#                                             'width': 51}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/sJy1IJNVSgqnOH66h35w_Vassily_Kandinsky%2C_1927_-_Molle_rudesse.jpg'}],
#   'Bio': 'Wassily Kandinsky\xa0(Васи́лий Канди́нский) was an influential '
#          'Russian painter and art theorist. He is credited with painting one '
#          'of the first purely\xa0abstract\xa0works. Born in Moscow, Kandinsky '
#          'spent his childhood in\xa0Odessa. He enrolled at the\xa0University '
#          'of Moscow, studying law and economics. Successful in his '
#          'profession—he was offered a professorship (chair of\xa0Roman Law) at '
#          'the\xa0University of Dorpat—Kandinsky began painting studies '
#          '(life-drawing, sketching and anatomy) at the age of\xa030.\n',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Abstract Expressionism', 'Der Blaue Reiter', 'Modern art'],
#   'Name': 'Wassily Kandinsky',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'images.jpg',
#                    'id': 'attdjq5uuG9U8ZHOj',
#                    'size': 3310,
#                    'thumbnails': {'full': {'height': 272,
#                                            'url': 'https://dl.airtable.com/jbuAxhUiQ3Wibm3iaerA_full_images.jpg',
#                                            'width': 185},
#                                   'large': {'height': 272,
#                                             'url': 'https://dl.airtable.com/QhY86izSduHP46AAKoBL_large_images.jpg',
#                                             'width': 185},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/DLSHuSTECU5Npc8uPFgx_small_images.jpg',
#                                             'width': 24}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/HgP3UEpBSWeTUaEVulqh_images.jpg'},
#                   {'filename': 'kelly_ellsworth_1.jpg',
#                    'id': 'attrG1NX15of4K50M',
#                    'size': 34330,
#                    'thumbnails': {'full': {'height': 546,
#                                            'url': 'https://dl.airtable.com/bBecYUg3QxqDynBhfIXe_full_kelly_ellsworth_1.jpg',
#                                            'width': 545},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/8WLdHQAgSFy8HMMotERJ_large_kelly_ellsworth_1.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/vf3p5f1jS2mmQeV1Qc3G_small_kelly_ellsworth_1.jpg',
#                                             'width': 36}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/eh1p6NOjREmHkS4EgjT4_kelly_ellsworth_1.jpg'},
#                   {'filename': 'ellsworth_kelly.jpg',
#                    'id': 'attuw7sa51ryV6klt',
#                    'size': 23913,
#                    'thumbnails': {'full': {'height': 569,
#                                            'url': 'https://dl.airtable.com/VEexdggJQqCjdmCeTy6s_full_ellsworth_kelly.jpg',
#                                            'width': 370},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/Cp2vSEjhRsWAE7ZYC9jk_large_ellsworth_kelly.jpg',
#                                             'width': 370},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/uReKiioIRmAxqKGrg3qK_small_ellsworth_kelly.jpg',
#                                             'width': 23}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/oNWE05dxQXyIgCjvtvBT_ellsworth_kelly.jpg'},
#                   {'filename': 'Spectrum-Colors-Arranged-By-Chance-II.jpg',
#                    'id': 'atti4UMdq9czrYYoL',
#                    'size': 335369,
#                    'thumbnails': {'full': {'height': 1365,
#                                            'url': 'https://dl.airtable.com/DQNKovGVTK2vZqhMcsuY_full_Spectrum-Colors-Arranged-By-Chance-II.jpg',
#                                            'width': 1366},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/oFsbWw4RQDqM1AeT7lkw_large_Spectrum-Colors-Arranged-By-Chance-II.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/PgtOEii9SZCjGGeohiU9_small_Spectrum-Colors-Arranged-By-Chance-II.jpg',
#                                             'width': 36}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/jYYzvd0uTtywGbO2n8Of_Spectrum-Colors-Arranged-By-Chance-II.jpg'},
#                   {'filename': 'Kelly__Ellsworth__Inv.Nr.0-1974-11_02.JPG',
#                    'id': 'att0ZggruYQhC8ChC',
#                    'size': 215673,
#                    'thumbnails': {'full': {'height': 1908,
#                                            'url': 'https://dl.airtable.com/F5HdltuTGqXP0wRV4zL5_full_Kelly__Ellsworth__Inv.Nr.0-1974-11_02.JPG',
#                                            'width': 2484},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/VJ5oETKZRytEmxAioXAd_large_Kelly__Ellsworth__Inv.Nr.0-1974-11_02.JPG',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/3f6tuD0rTduQcTyzRqhl_small_Kelly__Ellsworth__Inv.Nr.0-1974-11_02.JPG',
#                                             'width': 47}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/cEFOgwWQLOC3ZJ5vN9wq_Kelly__Ellsworth__Inv.Nr.0-1974-11_02.JPG'}],
#   'Bio': "Since the beginning of his career, Ellsworth Kelly's emphasis on "
#          'pure form and color and his impulse to suppress gesture in favor of '
#          'creating spatial unity have played a pivotal role in the development '
#          'of abstract art in America. A major influence on Pop Art, '
#          'Minimalism, hard-edge and color field painting, Ellsworth Kelly’s '
#          'best-known works are distinguished by sharply delineated shapes '
#          'flatly painted in vivid color, such as Colors for a Large Wall '
#          '(1951). His abstract paintings are inspired by the interplay of '
#          'light, space, and color in the architecture around him. In contrast, '
#          'Kelly’s automatic drawings feature delicate outlines of bodies and '
#          'flora.',
#   'Collection': ['recGqo38ZAIYg9z3e', 'rec6mjdBhVMGgwAx5'],
#   'Genre': ['Color Field'],
#   'Name': 'Ellsworth Kelly',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Leda.jpeg',
#                    'id': 'attuoGtQSGoeWEurX',
#                    'size': 55738,
#                    'thumbnails': {'full': {'height': 487,
#                                            'url': 'https://dl.airtable.com/0owq88p5Sfuvytk1RuDg_full_Leda.jpeg',
#                                            'width': 640},
#                                   'large': {'height': 487,
#                                             'url': 'https://dl.airtable.com/I1WvPxSYTDmzFGLWDECY_large_Leda.jpeg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/luUgOYKJSQewPuXwJi1D_small_Leda.jpeg',
#                                             'width': 47}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/dcVDcrL2TgOsCiyZ4MXg_Leda.jpeg'},
#                   {'filename': 'Mother_and_child.jpg',
#                    'id': 'att4MPT0gu8r2DZdv',
#                    'size': 38679,
#                    'thumbnails': {'full': {'height': 526,
#                                            'url': 'https://dl.airtable.com/LzA0PE8KQ3C9Hn5ZHWy8_full_Mother_and_child.jpg',
#                                            'width': 414},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/xdLWJVfRjmiOFc45XFEA_large_Mother_and_child.jpg',
#                                             'width': 414},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/a9oh3MZGSKWEPzDP9ux7_small_Mother_and_child.jpg',
#                                             'width': 28}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/7N4EIfmBTSKiYxDOxTJA_Mother_and_child.jpg'},
#                   {'filename': 'Sky-gate.jpg',
#                    'id': 'attsGNtljepdSppj3',
#                    'size': 10002210,
#                    'thumbnails': {'full': {'height': 2368,
#                                            'url': 'https://dl.airtable.com/f3Qi1iP7QYe837hhLHX4_full_Sky-gate.jpg',
#                                            'width': 3000},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/bg89ke5gTse8DLj9Qs7o_large_Sky-gate.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/JwAtRGKaSZOVSd1ku0Nn_small_Sky-gate.jpg',
#                                             'width': 46}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/Qr8zAePS1GSN04Ju741P_Sky-gate.jpg'},
#                   {'filename': 'Akari_Lamps.jpg',
#                    'id': 'attpYKQ4gldei2tWd',
#                    'size': 110954,
#                    'thumbnails': {'full': {'height': 696,
#                                            'url': 'https://dl.airtable.com/mtvYTSeNT8OKtlxht7HQ_full_Akari_Lamps.jpg',
#                                            'width': 960},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/DK9QBQkZQGWwOGzvAPxh_large_Akari_Lamps.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/A8sE3KRsSikA16zTkT83_small_Akari_Lamps.jpg',
#                                             'width': 50}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/QwJhSeRxSWus1DDrD1Mg_Akari_Lamps.jpg'}],
#   'Bio': 'Isamu Noguchi\xa0(野口 勇)\xa0was a prominent\xa0Japanese American\xa0'
#          'artist\xa0and\xa0landscape architect\xa0whose artistic career '
#          'spanned six decades, from the 1920s onward. Known for his\xa0'
#          'sculpture\xa0and public works, Noguchi also designed stage sets for '
#          'various\xa0Martha Graham\xa0productions, and several mass-produced '
#          'lamps and furniture pieces, some of which are still manufactured and '
#          'sold.',
#   'Collection': ['recuxHgKyHX10T4S3'],
#   'Genre': ['Experimental Sculpture'],
#   'Name': 'Isamu Noguchi',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'untitled.jpg',
#                    'id': 'attqtSbhqauz3DYZZ',
#                    'size': 158060,
#                    'thumbnails': {'full': {'height': 1024,
#                                            'url': 'https://dl.airtable.com/2KvZybESziOZikLyzoiP_full_untitled.jpg',
#                                            'width': 1142},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/IBmdRhBPSCGv8E8a8fRA_large_untitled.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/VX5y7KInSOCPjhkQFS6p_small_untitled.jpg',
#                                             'width': 40}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/qK5v7aWSuWVa5oMPLLfR_untitled.jpg'},
#                   {'filename': 'calder-bird.jpg',
#                    'id': 'atty7ZLbwCl5o0LvY',
#                    'size': 219287,
#                    'thumbnails': {'full': {'height': 550,
#                                            'url': 'https://dl.airtable.com/xu8MNEDQPqDmYjLKPTjf_full_calder-bird.jpg',
#                                            'width': 735},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/nK2tNLHQhm8Nvob1k5uT_large_calder-bird.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/cTLt8YgITYe7QuHfPjKi_small_calder-bird.jpg',
#                                             'width': 48}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/lxLuUH0BSpaobuZruwJJ_calder-bird.jpg'},
#                   {'filename': 'Rouge Triomphant.jpg',
#                    'id': 'attAQDm1vrW4W4Unl',
#                    'size': 564642,
#                    'thumbnails': {'full': {'height': 2752,
#                                            'url': 'https://dl.airtable.com/1rEdbzKaS4axkY7Dld5i_full_Rouge%20Triomphant.jpg',
#                                            'width': 2755},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/Kb2PvESR60VWfZ87V7QQ_large_Rouge%20Triomphant.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/ivRxHDdaT2Smbbb8Y9BW_small_Rouge%20Triomphant.jpg',
#                                             'width': 36}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/1GtRDFudRsqY5EN3TquT_Rouge%20Triomphant.jpg'}],
#   'Bio': 'Alexander Calder\xa0was an American\xa0sculptor\xa0known as the '
#          'originator of the\xa0mobile, a type of\xa0kinetic sculpture\xa0made '
#          'with delicately balanced or suspended components which move in '
#          'response to motor power or air currents. Calder’s stationary '
#          'sculptures are called\xa0stabiles. He also produced numerous wire '
#          'figures, notably for a miniature circus.\n',
#   'Collection': ['recuxHgKyHX10T4S3'],
#   'Genre': ['Surrealism', 'Modern art', 'Kinetic Art'],
#   'Name': 'Alexander Calder',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Color-Drawing.jpg',
#                    'id': 'att8enrlgYD3FiHXB',
#                    'size': 374784,
#                    'thumbnails': {'full': {'height': 550,
#                                            'url': 'https://dl.airtable.com/Jjp4XfNsQRmwUk6MdCAg_full_Color-Drawing.jpg',
#                                            'width': 433},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/6UtAUyxtRSGhCf6FE2b4_large_Color-Drawing.jpg',
#                                             'width': 433},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/v579gVvfS6p4R7QUzgEI_small_Color-Drawing.jpg',
#                                             'width': 28}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/H3Qw9STQq35qwmGn86mw_Color-Drawing.jpg'},
#                   {'filename': 'study_No._2.jpg',
#                    'id': 'attqEXWllptvGjPDQ',
#                    'size': 109204,
#                    'thumbnails': {'full': {'height': 700,
#                                            'url': 'https://dl.airtable.com/KPgH1bjITpulzfjt5AXv_full_study_No._2.jpg',
#                                            'width': 551},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/iVLRdt3AQ46gEEEuwgvJ_large_study_No._2.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/5hpwvURkRTevzd9BpFDK_small_study_No._2.jpg',
#                                             'width': 28}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/TJGRyxs7TwaqYgrqKmrh_study_No._2.jpg'},
#                   {'filename': 'three_gray_squares.jpg',
#                    'id': 'attHI8lwWwEoooJ24',
#                    'size': 109091,
#                    'thumbnails': {'full': {'height': 1200,
#                                            'url': 'https://dl.airtable.com/GiHKtqQ7R6oxm0bfLGrA_full_three_gray_squares.jpg',
#                                            'width': 890},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/Q0JLyfZBQ8WD3S2GhpRx_large_three_gray_squares.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/1veCnIC3QPmwA8zd8l6N_small_three_gray_squares.jpg',
#                                             'width': 27}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/Nu8pvf8uQAiJ8eKEcO3d_three_gray_squares.jpg'},
#                   {'filename': 'Streets_of_Tupelo.jpg',
#                    'id': 'att5TIJ00ppiNYQm3',
#                    'size': 27664,
#                    'thumbnails': {'full': {'height': 517,
#                                            'url': 'https://dl.airtable.com/rrcMdE1SjaDaRxl1cxgL_full_Streets_of_Tupelo.jpg',
#                                            'width': 639},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/CR46urXNRLaG2eU83L7g_large_Streets_of_Tupelo.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/HlZlUw1R5u6pZLN6P8i6_small_Streets_of_Tupelo.jpg',
#                                             'width': 44}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/R6ybBj0jRxmPKeNvp91P_Streets_of_Tupelo.jpg'}],
#   'Bio': 'Thornton Willis is an\xa0American\xa0abstract painter. He has '
#          'contributed to the\xa0New York School\xa0of painting since the late '
#          '1960s. Viewed as a member of the Third Generation of American '
#          'Abstract Expressionists, his work is associated with\xa0Abstract '
#          'Expressionism,\xa0Lyrical Abstraction,\xa0Process Art,\xa0'
#          'Postminimalism, Bio-morphic\xa0Cubism\xa0(a term he coined) and\xa0'
#          'Color Field painting.',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['American Abstract Expressionism', 'Color Field'],
#   'Name': 'Thornton Willis',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'No._18_1951.jpg',
#                    'id': 'attONu0jXlWNlHOxh',
#                    'size': 7416,
#                    'thumbnails': {'full': {'height': 260,
#                                            'url': 'https://dl.airtable.com/VR47jAErRSWwBCgzfmnx_full_No._18_1951.jpg',
#                                            'width': 213},
#                                   'large': {'height': 260,
#                                             'url': 'https://dl.airtable.com/pB4eyzqZQsSW9xeI2w30_large_No._18_1951.jpg',
#                                             'width': 213},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/q3aqfWzuR6KMxHdIIoAI_small_No._18_1951.jpg',
#                                             'width': 29}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/m3ySL7kR8mU9u9seQGAB_No._18_1951.jpg'},
#                   {'filename': 'Untitled_1954_RISD.jpg',
#                    'id': 'atteYo0fXP5bOpxt6',
#                    'size': 23636,
#                    'thumbnails': {'full': {'height': 640,
#                                            'url': 'https://dl.airtable.com/DwBK2nLKQQqnuC57BZc0_full_Untitled_1954_RISD.jpg',
#                                            'width': 385},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/XxsVD5xHT7qID17tG1qB_large_Untitled_1954_RISD.jpg',
#                                             'width': 385},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/YwC07XldRWm1xG44qlFL_small_Untitled_1954_RISD.jpg',
#                                             'width': 22}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/GMuCUGbkR8maca8BKOAw_Untitled_1954_RISD.jpg'},
#                   {'filename': 'Untitled_1954.jpg',
#                    'id': 'attneJn9hR5DtDns9',
#                    'size': 33352,
#                    'thumbnails': {'full': {'height': 640,
#                                            'url': 'https://dl.airtable.com/ebyZyKBR0epYw7sDuk6o_full_Untitled_1954.jpg',
#                                            'width': 385},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/oqF9mUFiTnyFJ7xkOuam_large_Untitled_1954.jpg',
#                                             'width': 385},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/D5D2TdNMTqiDVhxfu4NF_small_Untitled_1954.jpg',
#                                             'width': 22}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/2jZB5LUfRiaoX6YuKhpc_Untitled_1954.jpg'},
#                   {'filename': 'Untitled_(Red,_Orange).jpg',
#                    'id': 'attnicjT3NIYNL5Le',
#                    'size': 43346,
#                    'thumbnails': {'full': {'height': 640,
#                                            'url': 'https://dl.airtable.com/3OoiVXG0TWUiCUeIJHGA_full_Untitled_(Red%2C_Orange).jpg',
#                                            'width': 551},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/QL6G7zO2R46xr1UqXLBR_large_Untitled_(Red%2C_Orange).jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/mDeAgLSoRr2gx9DBM1ye_small_Untitled_(Red%2C_Orange).jpg',
#                                             'width': 31}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/O7dRll3Tz22Nu5bA5y2o_Untitled_(Red%2C_Orange).jpg'},
#                   {'filename': 'No._61_(Rust_and_Blue).jpg',
#                    'id': 'attpDkpjaf734NjM0',
#                    'size': 35819,
#                    'thumbnails': {'full': {'height': 600,
#                                            'url': 'https://dl.airtable.com/RlkPiNzQyKJdr2i1z8dK_full_No._61_(Rust_and_Blue).jpg',
#                                            'width': 480},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/14eKyDt3T5WH10kjn7uO_large_No._61_(Rust_and_Blue).jpg',
#                                             'width': 480},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/WZnmVRU3Tjyj6HLCYwkw_small_No._61_(Rust_and_Blue).jpg',
#                                             'width': 29}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/4RUO9GImRueqlBsQrW5c_No._61_(Rust_and_Blue).jpg'}],
#   'Bio': 'Mark Rothko is generally identified as an\xa0Abstract Expressionist. '
#          'With\xa0Jackson Pollock\xa0and\xa0Willem de Kooning, he is one of '
#          'the most famous postwar\xa0American artists.\n',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['American Abstract Expressionism', 'Color Field'],
#   'Name': 'Mark Rothko',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Four_Seasons_Mosaic_section.jpg',
#                    'id': 'attrxFDiSNonm5TPi',
#                    'size': 725916,
#                    'thumbnails': {'full': {'height': 872,
#                                            'url': 'https://dl.airtable.com/ZzXLk2EBT5eq5Nrg1aMS_full_Four_Seasons_Mosaic_section.jpg',
#                                            'width': 1024},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/z0Q89txTOiu1y5JB1hDZ_large_Four_Seasons_Mosaic_section.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/VXuR6ievQDuinLS8jWmr_small_Four_Seasons_Mosaic_section.jpg',
#                                             'width': 42}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/mNvDUXO8S5u5GRrWFFT2_Four_Seasons_Mosaic_section.jpg'},
#                   {'filename': 'david_and_bathsheba.jpg',
#                    'id': 'attCltNrI1czo705z',
#                    'size': 119333,
#                    'thumbnails': {'full': {'height': 560,
#                                            'url': 'https://dl.airtable.com/6y8eM8lSQN2baKanMEmR_full_david_and_bathsheba.jpg',
#                                            'width': 401},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/lK2yL0qzQCCSOCAw8g0O_large_david_and_bathsheba.jpg',
#                                             'width': 401},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/daJLiBEVSH27Ex87709h_small_david_and_bathsheba.jpg',
#                                             'width': 26}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/KWjHMfTQTYePZqC0eEMN_david_and_bathsheba.jpg'},
#                   {'filename': 'Chagall_Circus.jpg',
#                    'id': 'attvD91FYjd70s664',
#                    'size': 87755,
#                    'thumbnails': {'full': {'height': 473,
#                                            'url': 'https://dl.airtable.com/xzinyEgS3Oq2JesBIVJc_full_Chagall_Circus.jpg',
#                                            'width': 591},
#                                   'large': {'height': 473,
#                                             'url': 'https://dl.airtable.com/9VqrM3fDROqP2LE8aylp_large_Chagall_Circus.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/JpsKgzQRWasz5k140taV_small_Chagall_Circus.jpg',
#                                             'width': 45}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/7u2Jl0IyRbqyPci46BNz_Chagall_Circus.jpg'},
#                   {'filename': 'over-the-town-1918.jpg',
#                    'id': 'attiVo3p4YGPURL53',
#                    'size': 131932,
#                    'thumbnails': {'full': {'height': 619,
#                                            'url': 'https://dl.airtable.com/J93F6k9R2OESNtiLjIsA_full_over-the-town-1918.jpg',
#                                            'width': 800},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/FKIN8bVAQZmigge2mh1F_large_over-the-town-1918.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/djAqWq2BRWU1OtXCgSrQ_small_over-the-town-1918.jpg',
#                                             'width': 47}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/ILf7ke9RiWl70NojlRqn_over-the-town-1918.jpg'}],
#   'Bio': 'Marc Zakharovich Chagall was a\xa0Russian-French artist. Chagall saw '
#          'his work as "not the dream of one people but of all humanity". An '
#          'early\xa0modernist, he was associated with several major\xa0artistic '
#          'styles\xa0and created works in virtually every artistic medium, '
#          'including painting, book illustrations, stained glass, stage sets, '
#          'ceramic, tapestries and fine art prints.\n',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Symbolism', 'Expressionism', 'Fauvism', 'Modern art'],
#   'Name': 'Marc Chagall',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Marc-blue_horse.jpg',
#                    'id': 'attwGHVJIvgYbmQKN',
#                    'size': 64018,
#                    'thumbnails': {'full': {'height': 771,
#                                            'url': 'https://dl.airtable.com/3ov9lVXQVyX19PCvJhkQ_full_Marc-blue_horse.jpg',
#                                            'width': 576},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/q3MyvV1rTVSmA8iYDgBA_large_Marc-blue_horse.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/R9O1XwqgQ9ONBrrBIuIa_small_Marc-blue_horse.jpg',
#                                             'width': 27}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/YgGPao6TTY24n2sT0j2h_Marc-blue_horse.jpg'},
#                   {'filename': 'Landscape-with-house-and-two-cows.jpeg',
#                    'id': 'attmuEfiwdnFVZwcU',
#                    'size': 596526,
#                    'thumbnails': {'full': {'height': 921,
#                                            'url': 'https://dl.airtable.com/5S7RNxgdRZGeHtAOFESK_full_Landscape-with-house-and-two-cows.jpeg',
#                                            'width': 1005},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/wUiR9U3TzOyYYavK9jEN_large_Landscape-with-house-and-two-cows.jpeg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/6RHbPhHRjStMjl3UWbPQ_small_Landscape-with-house-and-two-cows.jpeg',
#                                             'width': 39}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/au5DRpogT6OHsFvuzxOW_Landscape-with-house-and-two-cows.jpeg'},
#                   {'filename': 'Marc-blue-black_fox.jpg',
#                    'id': 'attCmHbTcv0cosnA6',
#                    'size': 4362968,
#                    'thumbnails': {'full': {'height': 1875,
#                                            'url': 'https://dl.airtable.com/6WBkYEvNTSK9bBYQHyqm_full_Marc-blue-black_fox.jpg',
#                                            'width': 2364},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/yjmkQhFQRTKJGqRCsk6d_large_Marc-blue-black_fox.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/6wJdAq2sR9mGe0ANXn8R_small_Marc-blue-black_fox.jpg',
#                                             'width': 45}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/eTiQ8qFRA6r1Dx50JuFV_Marc-blue-black_fox.jpg'}],
#   'Bio': 'Franz Marc\xa0was a German\xa0painter\xa0and\xa0printmaker, one of '
#          'the key figures of the German\xa0Expressionist\xa0movement. He was a '
#          'founding member of\xa0Der Blaue Reiter\xa0(The Blue Rider), a '
#          'journal whose name later became synonymous with the circle of '
#          'artists collaborating in it.\n',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['Abstract Expressionism', 'Der Blaue Reiter', 'Modern art'],
#   'Name': 'Franz Marc',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'blue+light.jpg',
#                    'id': 'attLVumLibzCVC78C',
#                    'size': 52668,
#                    'thumbnails': {'full': {'height': 1000,
#                                            'url': 'https://dl.airtable.com/FnUW3gT3R3GJIcSiDD0F_full_blue%2Blight.jpg',
#                                            'width': 1000},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/Sn6Y8YoERLaHFZ6VSeUX_large_blue%2Blight.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/yPuixUODQVy2kxdZkGvU_small_blue%2Blight.jpg',
#                                             'width': 36}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/Y80E3oL8TYSDOcKOzxle_blue%2Blight.jpg'},
#                   {'filename': 'miya_ando_sui_getsu_ka_grid-copy.jpg',
#                    'id': 'attKMaJXwjMiuZdLI',
#                    'size': 442579,
#                    'thumbnails': {'full': {'height': 1000,
#                                            'url': 'https://dl.airtable.com/dt16nj4fSOyTkFBRaarb_full_miya_ando_sui_getsu_ka_grid-copy.jpg',
#                                            'width': 1000},
#                                   'large': {'height': 512,
# ...
#   'Bio': 'Frida Kahlo de Rivera\xa0was a\xa0Mexican painter best known for her '
#          "self-portraits. Kahlo's life began and ended in Mexico City, in her "
#          'home known as the\xa0Blue House. Her work has been celebrated in '
#          'Mexico as emblematic of national and\xa0indigenous\xa0tradition and '
#          'by feminists for its uncompromising depiction of the female '
#          'experience and form.',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Symbolism', 'Surrealism', 'Magical Realism'],
#   'Name': 'Frida Kahlo',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Master-Bill.jpg',
#                    'id': 'attwiwoecIfWHYlWm',
#                    'size': 22409,
#                    'thumbnails': {'full': {'height': 446,
#                                            'url': 'https://dl.airtable.com/3vePaL5RJGB3udbOgzv5_full_Master-Bill.jpg',
#                                            'width': 340},
#                                   'large': {'height': 446,
#                                             'url': 'https://dl.airtable.com/GvZb8g5STk2hyc858doG_large_Master-Bill.jpg',
#                                             'width': 340},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/J5OuDLapQMmWIU6Ejcj0_small_Master-Bill.jpg',
#                                             'width': 27}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/x1y9Rp20RMe6vUqwoxf2_Master-Bill.jpg'},
#                   {'filename': "The_Liver_Is_The_Cock's_Comb.jpg",
#                    'id': 'att07dHx1LHNHRBmA',
#                    'size': 71679,
#                    'thumbnails': {'full': {'height': 326,
#                                            'url': "https://dl.airtable.com/K8flcwXXRgONC50Wt1XZ_full_The_Liver_Is_The_Cock's_Comb.jpg",
#                                            'width': 440},
#                                   'large': {'height': 326,
#                                             'url': "https://dl.airtable.com/95dbH8PTTzCVA8qtqD3S_large_The_Liver_Is_The_Cock's_Comb.jpg",
#                                             'width': 440},
#                                   'small': {'height': 36,
#                                             'url': "https://dl.airtable.com/zzeFWkGPRNqLZ8ebliX1_small_The_Liver_Is_The_Cock's_Comb.jpg",
#                                             'width': 49}},
#                    'type': 'image/jpeg',
#                    'url': "https://dl.airtable.com/0QcnxAGRJCbgETKyt6Fa_The_Liver_Is_The_Cock's_Comb.jpg"},
#                   {'filename': 'Garden-in-Sochi-1941.jpg',
#                    'id': 'attzVTQd6Xpi1EGqp',
#                    'size': 400575,
#                    'thumbnails': {'full': {'height': 971,
#                                            'url': 'https://dl.airtable.com/PwCdFFgSmaReJLigtnEq_full_Garden-in-Sochi-1941.jpg',
#                                            'width': 1366},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/3erjc5N6Rhm4gGKU2kzK_large_Garden-in-Sochi-1941.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/OwtE5NmRtawB4ubqI6GP_small_Garden-in-Sochi-1941.jpg',
#                                             'width': 51}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/RxxKHt90TTeitDBmqfkp_Garden-in-Sochi-1941.jpg'}],
#   'Bio': 'Arshile Gorky\xa0had a seminal influence on\xa0Abstract '
#          'Expressionism. As such, his works were often speculated to have been '
#          'informed by the suffering and loss he experienced of the\xa0Armenian '
#          'Genocide.\n'
#          '\n',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['Abstract Expressionism', 'Modern art'],
#   'Name': 'Arshile Gorky',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'The_Sun.jpg',
#                    'id': 'attNIEYhExe4q53lp',
#                    'size': 194051,
#                    'thumbnails': {'full': {'height': 579,
#                                            'url': 'https://dl.airtable.com/0ThfL9nQSy1p6fGcC2PQ_full_The_Sun.jpg',
#                                            'width': 1000},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/YHJpBuCQTlaPh87v95TW_large_The_Sun.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/MYAGR1B9SSmgLQEwdQgg_small_The_Sun.jpg',
#                                             'width': 62}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/ZrAa1VHgRluhGihjoJlg_The_Sun.jpg'},
#                   {'filename': 'Munch_Det_Syke_Barn_1896.jpg',
#                    'id': 'attVjzN5X8xdWoc2W',
#                    'size': 425603,
#                    'thumbnails': {'full': {'height': 1500,
#                                            'url': 'https://dl.airtable.com/jOd0FXchSiiqZYOpdiGe_full_Munch_Det_Syke_Barn_1896.jpg',
#                                            'width': 1458},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/VVpi4DxYQIeHdoStBriP_large_Munch_Det_Syke_Barn_1896.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/fSNluujMSdSesFHx5mJV_small_Munch_Det_Syke_Barn_1896.jpg',
#                                             'width': 35}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/mSFaqPdrSzaLsNeOM7gC_Munch_Det_Syke_Barn_1896.jpg'},
#                   {'filename': 'death-in-the-sickroom.jpg',
#                    'id': 'attnTOZBfCiHQhfy1',
#                    'size': 255101,
#                    'thumbnails': {'full': {'height': 765,
#                                            'url': 'https://dl.airtable.com/pgANoMx7S2WzNSFjcQH6_full_death-in-the-sickroom.jpg',
#                                            'width': 850},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/D2jX8wuiQFqu6PqmDlB9_large_death-in-the-sickroom.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/lzialq0ARTiF858WBL2K_small_death-in-the-sickroom.jpg',
#                                             'width': 40}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/0USjT35QmmxqiQjxpjJZ_death-in-the-sickroom.jpg'}],
#   'Bio': 'Edvard Munch was a\xa0Norwegian painter\xa0and\xa0printmaker\xa0'
#          'whose intensely evocative treatment of psychological themes built '
#          'upon some of the main tenets of late 19th-century\xa0Symbolism\xa0'
#          'and greatly influenced\xa0German Expressionism\xa0in the early 20th '
#          'century. One of his most well-known works is\xa0The Scream\xa0of '
#          '1893.\n'
#          '\n',
#   'Collection': ['recO1TajNOl2Nw50y'],
#   'Genre': ['Abstract Expressionism', 'Modern art', 'Surrealism'],
#   'Name': 'Edvard Munch',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'Self Portrait in Long Striped Sweater.png',
#                    'id': 'attUUlhCqFv2ToEuH',
#                    'size': 2008952,
#                    'thumbnails': {'full': {'height': 1372,
#                                            'url': 'https://dl.airtable.com/SM8X0O6RTrySmMNshpbA_full_Self%20Portrait%20in%20Long%20Striped%20Sweater.png',
#                                            'width': 944},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/FumcBwrBR8S92tvlKzOp_large_Self%20Portrait%20in%20Long%20Striped%20Sweater.png',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/ptkkDheTjGrkUu2hOaiw_small_Self%20Portrait%20in%20Long%20Striped%20Sweater.png',
#                                             'width': 25}},
#                    'type': 'image/png',
#                    'url': 'https://dl.airtable.com/9xxNlqknSrmEU1Wbrdec_Self%20Portrait%20in%20Long%20Striped%20Sweater.png'},
#                   {'filename': 'louisa_matthiasdottir.jpg',
#                    'id': 'attNcKhQ3sHfw0Foq',
#                    'size': 361513,
#                    'thumbnails': {'full': {'height': 950,
#                                            'url': 'https://dl.airtable.com/hMWqCyhrSZW3Hck2aPEf_full_louisa_matthiasdottir.jpg',
#                                            'width': 1404},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/L4WkMOsVRHuvu8IUCyw8_large_louisa_matthiasdottir.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/JfkRJPIHRNysMmgzJqNx_small_louisa_matthiasdottir.jpg',
#                                             'width': 53}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/Yzdh0bO8Qfm3pNAQki2H_louisa_matthiasdottir.jpg'},
#                   {'filename': 'self-portrait-in-landscape.jpg',
#                    'id': 'atthrZ5E00cl6dlRb',
#                    'size': 23154,
#                    'thumbnails': {'full': {'height': 397,
#                                            'url': 'https://dl.airtable.com/TZPQBZhTeuYq3YEEKr58_full_self-portrait-in-landscape.jpg',
#                                            'width': 508},
#                                   'large': {'height': 397,
#                                             'url': 'https://dl.airtable.com/frlih5FlSbmHtJAByOJD_large_self-portrait-in-landscape.jpg',
#                                             'width': 508},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/bQjyuN2BSQBxzCd4GHy3_small_self-portrait-in-landscape.jpg',
#                                             'width': 46}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/P37MwE7FTSScdgcy5Vhj_self-portrait-in-landscape.jpg'}],
#   'Bio': 'Matthíasdóttir was born in\xa0Reykjavík. She showed artistic ability '
#          'at an early age, and studied first in\xa0Denmark\xa0and then '
#          'under\xa0Marcel Gromaire\xa0in\xa0Paris. Her early paintings, dating '
#          'from the late 1930s, established her as a leading figure in the '
#          'Icelandic\xa0avant-garde\xa0community (many of whom met together in '
#          'a house in Reykjavík called\xa0Unuhús). In these paintings, subjects '
#          'are painted with a broad brush, emphasizing geometric form. These '
#          "paintings already show much of the character of Matthíasdóttir's "
#          'mature work, but are more subdued in color.\n',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['Abstract Expressionism'],
#   'Name': 'Louisa Matthíasdóttir',
#   'On Display?': True},
#  {'Attachments': [{'filename': 'The_Gate.jpg',
#                    'id': 'attfVD69ey1joo2GZ',
#                    'size': 67939,
#                    'thumbnails': {'full': {'height': 573,
#                                            'url': 'https://dl.airtable.com/NioPizJS0uru7U2Stc5m_full_The_Gate.jpg',
#                                            'width': 368},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/Fh11UdjTJaoWn0OwYSkj_large_The_Gate.jpg',
#                                             'width': 368},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/mxP2tAWGTPC4HRzhuSxW_small_The_Gate.jpg',
#                                             'width': 23}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/2lOTCfQERxGMtXbsMDrr_The_Gate.jpg'},
#                   {'filename': 'the-conjuror.jpg',
#                    'id': 'attJIFcw31jvBQDfh',
#                    'size': 1075086,
#                    'thumbnails': {'full': {'height': 1600,
#                                            'url': 'https://dl.airtable.com/n8oZ3URC6CeBPkOokAhi_full_the-conjuror.jpg',
#                                            'width': 1220},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/X9JFMxgEQkGN5voPJaDi_large_the-conjuror.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/Fgt3al9fQPipXEHkZNDZ_small_the-conjuror.jpg',
#                                             'width': 27}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/U0UXnbqcSCWKpfq50MeP_the-conjuror.jpg'},
#                   {'filename': 'fruit-bowl-with-apples.png',
#                    'id': 'attrETA1O9dz9veTf',
#                    'size': 2306263,
#                    'thumbnails': {'full': {'height': 1202,
#                                            'url': 'https://dl.airtable.com/5Vf8xv69T8O9ncobaI0c_full_fruit-bowl-with-apples.png',
#                                            'width': 1015},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/rcVGyKY9TeOWFiIn5rAf_large_fruit-bowl-with-apples.png',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/vozEA4j5RXWFGQpfSrqL_small_fruit-bowl-with-apples.png',
#                                             'width': 30}},
#                    'type': 'image/png',
#                    'url': 'https://dl.airtable.com/45lmaXUOT9uNLDohoN9n_fruit-bowl-with-apples.png'},
#                   {'filename': 'the-golden-wall.jpg',
#                    'id': 'attcQ7g8JDAA1FgEZ',
#                    'size': 154804,
#                    'thumbnails': {'full': {'height': 676,
#                                            'url': 'https://dl.airtable.com/ITtPo1kNTUytRw7quO3A_full_the-golden-wall.jpg',
#                                            'width': 800},
#                                   'large': {'height': 512,
#                                             'url': 'https://dl.airtable.com/nx23ZVrRIeKJEEZibTLM_large_the-golden-wall.jpg',
#                                             'width': 512},
#                                   'small': {'height': 36,
#                                             'url': 'https://dl.airtable.com/4koYYgeWQjegASs1YYjH_small_the-golden-wall.jpg',
#                                             'width': 43}},
#                    'type': 'image/jpeg',
#                    'url': 'https://dl.airtable.com/u1aeqCxSQ96B28sCGRYq_the-golden-wall.jpg'}],
#   'Bio': 'Hans Hofmann was a German-born American\xa0abstract expressionist\xa0'
#          'painter.\n',
#   'Collection': ['recMxKoXA1F8L3uJF'],
#   'Genre': ['Abstract Expressionism', 'Modern art'],
#   'Name': 'Hans Hofmann',
#   'On Display?': True}]

# %%
# Sort Implicit
records = airtable.get_all(maxRecords=2, sort=["-Name"], fields='Name')
pprint(records)
# Out:
# [{'createdTime': '2015-02-09T23:40:46.000Z',
#   'fields': {'Name': 'Willem de Kooning'},
#   'id': 'rec3osnAbyGTxswiY'},
#  {'createdTime': '2015-02-10T00:50:32.000Z',
#   'fields': {'Name': 'Wassily Kandinsky'},
#   'id': 'rec7UPYRc3MRaGpxw'}]

# %%
# Sort Explicit
records = airtable.get_all(maxRecords=2, sort=[("Name", 'desc')])
pprint(records[0]['fields']['Name'])
# Out:
# 'Willem de Kooning'

# %%
# Replace - If Field is not included, it will be set to null
# records = airtable.replace_by_field("COLUMN_ID", '4', {'COLUMN_ID': '4', 'COLUMN_UPDATE':'A'})
# print(records)

# %%
# Update - Only included fields are updated. Rest is left as is.
# records = airtable.update_by_field("COLUMN_INT", '4', {'COLUMN_UPDATE':'B'})
# print(records)

# %%
# base_key = 'appJMY16gZDQrMWpA'
# table_name = 'TestLink'
# airtable = Airtable(base_key, table_name)
# airtable.get_all()

# airtable.insert({'Name': 'Two', 'Link': ['rec0LQoJ4Vgp8fPty', 'rec0oyCWScnRI1wYI']})
# Out:
# {'createdTime': '2017-11-07T14:22:24.300Z',
#  'fields': {'Link': ['rec0LQoJ4Vgp8fPty', 'rec0oyCWScnRI1wYI'], 'Name': 'Two'},
#  'id': 'recRq24OVdmcOvvTo'}
